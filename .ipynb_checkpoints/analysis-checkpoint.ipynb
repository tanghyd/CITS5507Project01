# %%
import glob

import pandas as pd

import plotly.express as px

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# %%
columns = ['Algorithm','Construct','Threads','Size','Cutoff','Duration']
df = pd.concat([
    pd.read_csv(file, names=columns)
    for file in glob.glob('results/*.csv')
])

# data saving error
# df.loc[df.Construct == 'serial', 'Cutoff'] = 0

# %%
# df = pd.read_csv('results/TEST.csv', names=columns)
# # df = df.loc[df.Size != 100000]
# # df = df.loc[df.Size != 10000]
# # df = df.loc[df.Size != 1000]
# df = df.sort_values(['Size','Duration'])
# df

# %%
df
# Out:
#     Algorithm Construct  Threads      Size  Cutoff  Duration
# 0       merge    serial        1      1000       0  0.000203
# 1       merge    serial        1      1000       0  0.000163
# 2       merge    serial        1      1000       0  0.000177
# 3       merge    serial        1      1000       0  0.000148
# 4       merge    serial        1      1000       0  0.000156
# ..        ...       ...      ...       ...     ...       ...
# 620     quick  sections       16  10000000    1000  2.138845
# 621     quick     tasks       16  10000000    1000  0.344319
# 622     quick  sections       16  10000000    1000  2.168916
# 623     quick     tasks       16  10000000    1000  0.342963
# 624     quick  sections       16  10000000    1000  2.088940
#
# [1445 rows x 6 columns]

# %%
help(go.Figure)
# Out:
# Help on class Figure in module plotly.graph_objs._figure:
#
# class Figure(plotly.basedatatypes.BaseFigure)
#  |  Figure(data=None, layout=None, frames=None, skip_invalid=False, **kwargs)
#  |
#  |  Base class for all figure types (both widget and non-widget)
#  |
#  |  Method resolution order:
#  |      Figure
#  |      plotly.basedatatypes.BaseFigure
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, data=None, layout=None, frames=None, skip_invalid=False, **kwargs)
#  |      Create a new :class:Figure instance
#  |
#  |      Parameters
#  |      ----------
#  |      data
#  |          The 'data' property is a tuple of trace instances
#  |          that may be specified as:
#  |            - A list or tuple of trace instances
#  |              (e.g. [Scatter(...), Bar(...)])
#  |            - A single trace instance
#  |              (e.g. Scatter(...), Bar(...), etc.)
#  |            - A list or tuple of dicts of string/value properties where:
# ...

# %%
quick = df.loc[
    (df.Algorithm == 'quick') &
    (df.Cutoff == 0) &
    (df.Construct == 'tasks'),
    ['Threads', 'Size', 'Duration']
]
quick
# Out:
#      Threads      Size  Duration
# 5          2      1000  0.001606
# 7          2      1000  0.001445
# 9          2      1000  0.001429
# 11         2      1000  0.001445
# 13         2      1000  0.001258
# ..       ...       ...       ...
# 595       16  10000000  0.688066
# 597       16  10000000  0.692657
# 599       16  10000000  0.701827
# 601       16  10000000  0.669633
# 603       16  10000000  0.628405
#
# [100 rows x 3 columns]

# %%
quick_data = quick.groupby(['Threads', 'Size'])['Duration'].agg({'mean', 'min', 'max', 'std'})
quick_data
# Out:
#                       mean       max       std       min
# Threads Size
# 2       1000      0.001437  0.001606  0.000123  0.001258
#         10000     0.002434  0.002541  0.000115  0.002295
#         100000    0.012746  0.013699  0.000782  0.011760
#         1000000   0.117624  0.120003  0.001389  0.116727
#         10000000  1.306745  1.345522  0.024832  1.277152
# 4       1000      0.002240  0.002365  0.000072  0.002190
#         10000     0.006200  0.007790  0.001076  0.005227
#         100000    0.015013  0.018038  0.001822  0.013353
#         1000000   0.077937  0.080653  0.002634  0.074095
#         10000000  0.717077  0.728930  0.008207  0.707050
# 8       1000      0.002100  0.002232  0.000083  0.002024
#         10000     0.011879  0.018754  0.003897  0.009095
#         100000    0.021742  0.023888  0.001336  0.020410
#         1000000   0.073995  0.080685  0.006109  0.064607
#         10000000  0.538931  0.583794  0.035271  0.493489
# ...

# %%
quick_data.index
# Out:
# MultiIndex([( 2,     1000),
#             ( 2,    10000),
#             ( 2,   100000),
#             ( 2,  1000000),
#             ( 2, 10000000),
#             ( 4,     1000),
#             ( 4,    10000),
#             ( 4,   100000),
#             ( 4,  1000000),
#             ( 4, 10000000),
#             ( 8,     1000),
#             ( 8,    10000),
#             ( 8,   100000),
#             ( 8,  1000000),
#             ( 8, 10000000),
#             (16,     1000),
#             (16,    10000),
#             (16,   100000),
#             (16,  1000000),
#             (16, 10000000)],
#            names=['Threads', 'Size'])

# %%
thread2 = quick_data.loc[quick_data.index.get_level_values('Threads') == 2]

# %%
thread2['std']
# Out:
# Threads  Size
# 2        1000        0.000123
#          10000       0.000115
#          100000      0.000782
#          1000000     0.001389
#          10000000    0.024832
# Name: std, dtype: float64

# %%
thread2['max'].values - thread2['min'].values
# Out:
# array([0.00034806, 0.00024571, 0.0019395 , 0.00327667, 0.06837019])

# %%
thread2.index.get_level_values('Size').values
# Out:
# array([    1000,    10000,   100000,  1000000, 10000000])

# %%
import plotly.graph_objects as go

fig = go.Figure(
    layout={
        'title': {
            'text': 'Quick Sort Algorithm Runtime'
        }
    }
)

fig.add_trace(
    go.Scatter(
        x=thread2.index.get_level_values('Size').values,
        y=thread2['mean'].values,
        name='Line',
        error_y=dict(
            type='data',
            symmetric=False,
            array=thread2['max'].values - thread2['mean'].values,
            arrayminus=thread2['mean'].values - thread2['min'].values
        ),
        fillcolor='red'
    )
)
fig.update_yaxes(type="log")
fig.show()
# Out:
# <div>                            <div id="1a84f4c9-b725-4ef8-b12e-485ab0ec3977" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a84f4c9-b725-4ef8-b12e-485ab0ec3977")) {                    Plotly.newPlot(                        "1a84f4c9-b725-4ef8-b12e-485ab0ec3977",                        [{"error_y": {"array": [0.00016946559480857104, 0.000107255397597328, 0.0009529730101348836, 0.002379428796120908, 0.038776773796416864], "arrayminus": [0.00017859939543996006, 0.00013845459325239045, 0.0009865219966741275, 0.0008972431998699876, 0.029593418195145382], "symmetric": false, "type": "data"}, "fillcolor": "red", "name": "Line", "type": "scatter", "x": [1000, 10000, 100000, 1000000, 10000000], "y": [0.001436652397387661, 0.0024336085945833473, 0.012746
# ...

# %%
x_values
# Out:
# array([    1000,    10000,   100000,  1000000, 10000000])

# %%
y_values
# Out:
# array([0.00143665, 0.00243361, 0.01274609, 0.11762386, 1.30674502])

# %%
y_error
# Out:
# array([0.00034806, 0.00024571, 0.0019395 , 0.00327667, 0.06837019])

# %%
quick_data = (
    df.loc[
        (df.Algorithm == 'quick') &
#         (df.Cutoff == 0) &
        (df.Construct == 'tasks'),
        ['Threads', 'Cutoff', 'Size', 'Duration']
    ]
    .groupby(['Threads', 'Cutoff', 'Size'])['Duration']
    .agg({'mean', 'min', 'max', 'std'})
)

quick_data
# Out:
#                              mean       max       std       min
# Threads Cutoff Size
# 2       0      1000      0.001437  0.001606  0.000123  0.001258
#                10000     0.002434  0.002541  0.000115  0.002295
#                100000    0.012746  0.013699  0.000782  0.011760
#                1000000   0.117624  0.120003  0.001389  0.116727
#                10000000  1.306745  1.345522  0.024832  1.277152
#         100    1000      0.000120  0.000126  0.000007  0.000110
#                10000     0.001112  0.001145  0.000027  0.001080
#                100000    0.012722  0.013998  0.001287  0.010727
#                1000000   0.117744  0.125242  0.004255  0.114765
#                10000000  1.332864  1.380661  0.042218  1.296535
#         1000   1000      0.000145  0.000221  0.000042  0.000121
#                10000     0.000866  0.000962  0.000061  0.000809
#                100000    0.012647  0.013858  0.000987  0.011132
# ...

# %%
# fig = plt.figure(figsize=(20, 12))
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(16,6), sharex=True, sharey=True)

for i, cutoff in enumerate(quick_data.index.get_level_values('Cutoff').unique()):
    ax = axes[i]
    ax.set_title(f'Quick Sort Runtime vs. Array Size (Cutoff={cutoff})')

    
    # plot data
    for j, n_threads in enumerate(quick_data.index.get_level_values('Threads').unique()):
        data = quick_data.loc[
            (quick_data.index.get_level_values('Threads') == n_threads) &
            (quick_data.index.get_level_values('Cutoff') == cutoff)
        ]
        
        array_sizes = data.index.get_level_values('Size').values

        color=list(mcolors.TABLEAU_COLORS)[j]
        ax.plot(array_sizes, data['mean'].values, label=f'{n_threads} Threads', color=color)
        ax.errorbar(array_sizes, data['mean'].values, yerr=data['std'].values , fmt='o', markersize=4, color=color)
    
    if i == 0:
        ax.set_ylabel('Runtime (s)')
    ax.legend(loc='upper left')
        
    ax.set_xlabel('Array Size')
    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.grid()

fig.suptitle('Sorting Algorithm Runtimes in C (Log-Log Scale)')
fig.tight_layout()
fig.show()

# %%
fig = px.box(
    df,
    y='Duration', x='Algorithm', color='Size',
    facet_col='Cutoff', facet_col_wrap=3,
    facet_row='Construct',
    template='seaborn',
    log_y=True, 
    height=800,
#     boxmode="overlay",
    points='all',
    title='C Sorting Algorithm Runtimes',
    labels={
        "Duration": "Duration (s)",
        "Algorithm": "Sorting Algorithm",
     },
)

fig.update_xaxes(showgrid=True, gridwidth=2)#, gridcolor='LightPink')
fig.update_yaxes(showgrid=True, gridwidth=2)#, gridcolor='LightPink')

# for (algorithm, size) in means.index:
# for algorithm in means.index.get_level_values('Algorithm').unique():
#     trace = go.Scatter(means.loc[algorithm], y=)
#     fig.add_line(x=)
    # fig.add_line(x='Algorithm', y=, name="Last year")

fig.show()
# Out:
# <div>                            <div id="6733e7be-d897-4d2b-80cc-552c31ab152e" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6733e7be-d897-4d2b-80cc-552c31ab152e")) {                    Plotly.newPlot(                        "6733e7be-d897-4d2b-80cc-552c31ab152e",                        [{"alignmentgroup": "True", "boxpoints": "all", "hovertemplate": "Size=1000<br>Construct=serial<br>Cutoff=0<br>Sorting Algorithm=%{x}<br>Duration (s)=%{y}<extra></extra>", "legendgroup": "1000", "marker": {"color": "rgb(76,114,176)"}, "name": "1000", "notched": false, "offsetgroup": "1000", "orientation": "v", "showlegend": true, "type": "box", "x": ["merge", "merge", "merge", "merge", "merge", "enumeration", "enumeration", "enumeration", "enumeration", "enumerati
# ...

# %%
fig = px.line(
    df,
    y='Duration', x='Size', color='Algorithm',
    facet_col='Cutoff', facet_col_wrap=3,
    facet_row='Construct',
    template='seaborn',
    log_y=True, 
    height=800,
    title='C Sorting Algorithm Runtimes',
    labels={
        "Duration": "Duration (s)",
        "Algorithm": "Sorting Algorithm",
     },
)

fig.update_xaxes(showgrid=True, gridwidth=2)#, gridcolor='LightPink')
fig.update_yaxes(showgrid=True, gridwidth=2)#, gridcolor='LightPink')

# for (algorithm, size) in means.index:
# for algorithm in means.index.get_level_values('Algorithm').unique():
#     trace = go.Scatter(means.loc[algorithm], y=)
#     fig.add_line(x=)
    # fig.add_line(x='Algorithm', y=, name="Last year")

fig.show()
# Out:
# <div>                            <div id="f96473b9-578a-4a20-863d-c5f05359634f" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f96473b9-578a-4a20-863d-c5f05359634f")) {                    Plotly.newPlot(                        "f96473b9-578a-4a20-863d-c5f05359634f",                        [{"hovertemplate": "Sorting Algorithm=merge<br>Construct=serial<br>Cutoff=0<br>Size=%{x}<br>Duration (s)=%{y}<extra></extra>", "legendgroup": "merge", "line": {"color": "rgb(76,114,176)", "dash": "solid"}, "mode": "lines", "name": "merge", "showlegend": true, "type": "scattergl", "x": [1000, 1000, 1000, 1000, 1000, 10000, 10000, 10000, 10000, 10000, 100000, 100000, 100000, 100000, 100000, 1000000, 1000000, 1000000, 1000000, 1000000, 10000000, 10000000, 10000000, 1
# ...
